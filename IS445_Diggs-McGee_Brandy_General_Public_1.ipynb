# %%
import matplotlib.pyplot as plt

# Drop the NaN values to clean up the data
df_clean = df.dropna()

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

# Creating a bar graph
df_clean.plot(kind='bar', ax=ax, color=['red', 'blue', 'yellow', 'green'])

# Setting the labels and title
ax.set_xlabel("Potential Phase Composition")
ax.set_ylabel("Composition Percentage (%)")
ax.set_title("Hydration Products Composition")
ax.set_xticklabels(df_clean['Potential Phase Composition (%)'], rotation=45)

# Adding legend
ax.legend(["C1", "C2", "C3", "C4"])

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import matplotlib.pyplot as plt
#       3 # Drop the NaN values to clean up the data
# ----> 4 df_clean = df.dropna()
#       6 # Plotting
#       7 fig, ax = plt.subplots(figsize=(10, 6))
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the Excel file
file_path = r'G:\445\Hydration Products.xlsx'
df = pd.read_excel(file_path)

# Drop the NaN values to clean up the data
df_clean = df.dropna()

# Trimming spaces from column names if necessary
df_clean.columns = df_clean.columns.str.strip()

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

# Creating a bar graph
df_clean.plot(kind='bar', ax=ax, color=['red', 'blue', 'yellow', 'green'])

# Setting the labels and title
ax.set_xlabel("Potential Phase Composition")
ax.set_ylabel("Composition Percentage (%)")
ax.set_title("Hydration Products Composition")
ax.set_xticklabels(df_clean['Potential Phase Composition (%)'], rotation=45)

# Adding legend
ax.legend(["C1", "C2", "C3", "C4"])

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the Excel file
file_path = r'G:\445\Hydration Products.xlsx'
df = pd.read_excel(file_path)

# Drop the NaN values to clean up the data
df_clean = df.dropna()

# Trimming spaces from column names if necessary
df_clean.columns = df_clean.columns.str.strip()

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

# Creating a bar graph
df_clean.plot(kind='bar', ax=ax, color=['red', 'blue', 'yellow', 'green'])

# Setting the labels and title
ax.set_xlabel("Potential Phase Composition")
ax.set_ylabel("Composition Percentage (%)")
ax.set_title("Hydration Products Composition")
ax.set_xticklabels(df_clean['Potential Phase Composition (%)'], rotation=45)

# Adding legend
ax.legend(["C1", "C2", "C3", "C4"])

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the Excel file
file_path = r'G:\445\Hydration Products.xlsx'
df = pd.read_excel(file_path)

# Drop the NaN values to clean up the data
df_clean = df.dropna()

# Trimming spaces from column names if necessary
df_clean.columns = df_clean.columns.str.strip()

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

# Extracting the 'Potential Phase Composition (%)' column for x-axis labels
x_labels = df_clean['Potential Phase Composition (%)'].values

# Plotting each sample's data in its respective color
for column, color in zip(df_clean.columns[1:], ['red', 'blue', '#ffd343', 'green']):
    ax.bar(x_labels, df_clean[column], label=column, color=color)

# Setting the labels and title
ax.set_xlabel("Potential Phase Composition")
ax.set_ylabel("Composition Percentage (%)")
ax.set_title("Hydration Products Composition by Sample")
ax.set_xticks(x_labels)
ax.set_xticklabels(x_labels, rotation=45)

# Adding legend
ax.legend()

# Show the plot
plt.show()

# %%
# It seems that numpy was not imported which is required for np.arange to work. Let's correct this.

import numpy as np

import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the Excel file
file_path = r'G:\445\Hydration Products.xlsx'
df = pd.read_excel(file_path)

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

# Width of a bar
bar_width = 0.2

# Positions of the left bar-boundaries
bar_positions = np.arange(len(df))

# Setting the colors
colors = ['red', 'blue', '#ffd343', 'green']

# Plotting bars for each sample
for i, (sample, color) in enumerate(zip(df.columns, colors)):
    ax.bar(bar_positions + i * bar_width, df[sample], width=bar_width, label=sample, color=color)

# Setting the position and labels for X-ticks
ax.set_xticks(bar_positions + bar_width * 1.5)
ax.set_xticklabels(df.index)

# Setting the labels and title
ax.set_xlabel("Potential Phase Composition (%)")
ax.set_ylabel("Composition Percentage (%)")
ax.set_title("Hydration Products Composition by Sample")

# Adding legend
ax.legend()

# Show the plot
plt.tight_layout()  # Adjust layout to fit everything
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 26
#      24 # Plotting bars for each sample
#      25 for i, (sample, color) in enumerate(zip(df.columns, colors)):
# ---> 26     ax.bar(bar_positions + i * bar_width, df[sample], width=bar_width, label=sample, color=color)
#      28 # Setting the position and labels for X-ticks
#      29 ax.set_xticks(bar_positions + bar_width * 1.5)
#
# File C:\Anaconda\Lib\site-packages\matplotlib\__init__.py:1446, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1443 @functools.wraps(func)
#    1444 def inner(ax, *args, data=None, **kwargs):
#    1445     if data is None:
# -> 1446         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448     bound = new_sig.bind(ax, *args, **kwargs)
#    1449     auto_label = (bound.arguments.get(label_namer)
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the Excel file
file_path = r'G:\445\Hydration Products.xlsx'
df = pd.read_excel(file_path)

# Assuming the first column is the 'Potential Phase Composition (%)' and needs to be set as the index
df.set_index(df.columns[0], inplace=True)

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

# Width of a bar
bar_width = 0.2

# Positions of the left bar-boundaries
bar_positions = np.arange(len(df))

# Setting the colors for C1 to C4
colors = ['red', 'blue', '#ffd343', 'green']

# Plotting bars for each sample
for i, (sample, color) in enumerate(zip(df.columns, colors)):
    # Offsetting each bar's position to avoid overlap
    ax.bar(bar_positions + i * bar_width, df[sample], width=bar_width, label=sample, color=color)

# Setting the position and labels for X-ticks
# Centering the x-ticks between the groups of bars
ax.set_xticks(bar_positions + bar_width * (len(df.columns) / 2 - 0.5))
ax.set_xticklabels(df.index)

# Setting the labels and title
ax.set_xlabel("Potential Phase Composition (%)")
ax.set_ylabel("Composition Percentage (%)")
ax.set_title("Hydration Products Composition by Sample")

# Adding legend
ax.legend(title="Samples")

# Show the plot
plt.tight_layout()  # Adjust layout to fit everything
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 27
#      24 # Plotting bars for each sample
#      25 for i, (sample, color) in enumerate(zip(df.columns, colors)):
#      26     # Offsetting each bar's position to avoid overlap
# ---> 27     ax.bar(bar_positions + i * bar_width, df[sample], width=bar_width, label=sample, color=color)
#      29 # Setting the position and labels for X-ticks
#      30 # Centering the x-ticks between the groups of bars
#      31 ax.set_xticks(bar_positions + bar_width * (len(df.columns) / 2 - 0.5))
#
# File C:\Anaconda\Lib\site-packages\matplotlib\__init__.py:1446, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1443 @functools.wraps(func)
#    1444 def inner(ax, *args, data=None, **kwargs):
#    1445     if data is None:
# -> 1446         return func(ax, *map(sanitize_sequence, args), **kwargs)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the data from the Excel file
file_path = r'G:\445\Hydration Products.xlsx'
df = pd.read_excel(file_path)

# Set the index to the 'Potential Phase Composition (%)' column, ensuring it's treated as strings
df.set_index(df.columns[0].astype(str), inplace=True)

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

# Width of a bar
bar_width = 0.2

# Positions of the left bar-boundaries
bar_positions = np.arange(len(df))

# Setting the colors for C1 to C4
colors = ['red', 'blue', '#ffd343', 'green']

# Plotting bars for each sample
for i, (sample, color) in enumerate(zip(df.columns, colors)):
    # Offsetting each bar's position to avoid overlap
    ax.bar(bar_positions + i * bar_width, df[sample].values, width=bar_width, label=sample, color=color)

# Setting the position and labels for X-ticks
ax.set_xticks(bar_positions + bar_width * (len(df.columns) / 2 - 0.5))
ax.set_xticklabels(df.index, rotation=45)

# Setting the labels and title
ax.set_xlabel("Potential Phase Composition (%)")
ax.set_ylabel("Composition Percentage (%)")
ax.set_title("Hydration Products Composition by Sample")

# Adding legend
ax.legend(title="Samples")

# Show the plot
plt.tight_layout()  # Adjust layout to fit everything
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 10
#       7 df = pd.read_excel(file_path)
#       9 # Set the index to the 'Potential Phase Composition (%)' column, ensuring it's treated as strings
# ---> 10 df.set_index(df.columns[0].astype(str), inplace=True)
#      12 # Plotting
#      13 fig, ax = plt.subplots(figsize=(10, 6))
#
# AttributeError: 'str' object has no attribute 'astype'

# %%
#Datasent Inforamtion
# What is the "name" of the dataset? Cement Paste Data
# Where did you obtain it? I collected the samples
# Where can we obtain it? (i.e., URL): Will be available after first publication.
# What is the license of the dataset? What are we allowed to do with it? None and do not share.
# How big is it in file size and in items? 203 KB

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import textwrap
import matplotlib.pyplot as plt
import pandas as pd
import os
from matplotlib.ticker import MultipleLocator

# Sample DataFrame structure based on the provided image
data = {
    'Potential Phase Composition (%)': ['C3S', 'C2S', 'C3A', 'C4AF'],
    'C1': [54.7, 14.4, 10.4, 6.4],
    'C2': [52, 15, 7, 8],
    'C3': [65, 7, 7, 10],
    'C4': [60, 30, 12, 12]
}

# Convert the dictionary to a DataFrame
df = pd.DataFrame(data)

# Set the 'Potential Phase Composition (%)' as the index of the DataFrame
df.set_index('Potential Phase Composition (%)', inplace=True)

def customize_ticks(ax, x_major, x_minor, y_major, y_minor):
    ax.xaxis.set_major_locator(MultipleLocator(x_major))
    ax.xaxis.set_minor_locator(MultipleLocator(x_minor))
    ax.yaxis.set_major_locator(MultipleLocator(y_major))
    ax.yaxis.set_minor_locator(MultipleLocator(y_minor))
    ax.tick_params(axis='both', which='major', length=5, width=0.5, labelsize=12)
    ax.tick_params(axis='both', which='minor', length=2.5, width=0.5)
    return ax

plt.rc('font', family='Times New Roman', weight='regular', size=12)
lfs = 12

# Plotting
fig, ax = plt.subplots(figsize=(10, 6))

# Width of a bar
bar_width = 0.2

# Positions of the left bar-boundaries
bar_positions = np.arange(len(df))

# Setting the colors for C1 to C4
colors = ['red', 'blue', '#ffd343', 'green']

# Plotting bars for each sample
for i, sample in enumerate(df.columns):
    # Offsetting each bar's position to avoid overlap
    ax.bar(bar_positions + i * bar_width, df[sample], width=bar_width, label='C' + str(i+1), color=colors[i])

# Setting the position and labels for X-ticks
ax.set_xticks(bar_positions + bar_width * (len(df.columns) / 2 - 0.5))
ax.set_xticklabels(df.index, rotation=45)

# Setting the labels and title
ax.set_xlabel("Potential Phase Composition (%)")
ax.set_ylabel("Composition Percentage (%)")
ax.set_title("Hydration Products Composition by Sample")

# Adding legend
ax.legend(title="Samples")

# Show the plot
plt.tight_layout()  # Adjust layout to fit everything
plt.show()

# Save the plot
filename = os.path.join(r'C:\Users\brandyd2\Downloads', "Hydration Products.png")
fig.savefig(filename, dpi=300, bbox_inches='tight')

# Display the plot
plt.show()
