# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
from matplotlib.ticker import MultipleLocator

###GARG FORMAT##########################################################
def customize_ticks(ax, x_major, x_minor, y_major, y_minor):
    """
    Customize the ticks on the x and y axes
    
    Parameters:
    ax (object): The axes object to customize
    x_major (int): The frequency for major ticks on the x-axis
    x_minor (int): The frequency for minor ticks on the x-axis
    y_major (int): The frequency for major ticks on the y-axis
    y_minor (int): The frequency for minor ticks on the y-axis
    
    Returns:
    ax (object): The customized axes object
    """
    
    # Set the frequency of major ticks on the x-axis
    ax.xaxis.set_major_locator(MultipleLocator(x_major))
    # Set the frequency of minor ticks on the x-axis
    ax.xaxis.set_minor_locator(MultipleLocator(x_minor))

    # Set the frequency of major ticks on the y-axis
    ax.yaxis.set_major_locator(MultipleLocator(y_major))
    # Set the frequency of minor ticks on the y-axis
    ax.yaxis.set_minor_locator(MultipleLocator(y_minor))

    # Set tick parameters: length, width, and size of labels for major ticks (labelsize also affects minor ticks)
    ax.tick_params(axis='both', which='major', length=5, width=0.5, labelsize=12)
    # Set tick parameters: length and width for minor ticks
    ax.tick_params(axis='both', which='minor', length=2.5, width=0.5)

    return ax
# Define the font properties for the plot
font = {'family' : 'Times New Roman',
        'weight' : 'regular',
        'size'   : 12}

# Apply font properties
plt.rc('font', family='Times New Roman', weight='regular', size=12)

# Define the font size for the labels
lfs = 12

# Load data from Excel sheets
file_path = (r'C:\Users\brandyd2\Downloads\231201_Infrared and Isothermal Data_Paste_Diggs_V14.xlsx')
sheets = ['Hours 40% Trail 7_Isocal', 'Hours 40% Trial 7_Infrared', 'Hours 55% Trial 7_Isocal', 'Hours 55% Trial 7_Infrared','Hours 70% Trail 7_IsoCal', 'Hours 70% Trial 7_Infrared']

# Define titles and column names for different methods
plot_titles = ['0.40 w/c Ratio', '0.55 w/c Ratio', '0.70 w/c Ratio']
columns_for_plots = [
    ('Time-c1-iso', 'mW/h-c1-iso', 'Time-c2-iso', 'mW/h-c2-iso', 'Time-c3-iso', 'mW/h-c3-iso', 'Time-c4-iso', 'mW/h-c4-iso'),
    ('Time-c1-ir', 'mW/h-c1-ir', 'Time-c2-ir', 'mW/h-c2-ir', 'Time-c3-ir', 'mW/h-c3-ir', 'Time-c4-ir', 'mW/h-c4-ir'),
    ('Time-c1-iso', 'mW/h-c1-iso', 'Time-c2-iso', 'mW/h-c2-iso', 'Time-c3-iso', 'mW/h-c3-iso', 'Time-c4-iso', 'mW/h-c4-iso'),
    ('Time-c1-ir', 'mW/h-c1-ir', 'Time-c2-ir', 'mW/h-c2-ir', 'Time-c3-ir', 'mW/h-c3-ir', 'Time-c4-ir', 'mW/h-c4-ir'),
    ('Time-c1-iso', 'mW/h-c1-iso', 'Time-c2-iso', 'mW/h-c2-iso', 'Time-c3-iso', 'mW/h-c3-iso', 'Time-c4-iso', 'mW/h-c4-iso'),
    ('Time-c1-ir', 'mW/h-c1-ir', 'Time-c2-ir', 'mW/h-c2-ir', 'Time-c3-ir', 'mW/h-c3-ir', 'Time-c4-ir', 'mW/h-c4-ir'),
    
]

# Define colors for each sample category
colors = {'mW/h-c1-iso': 'red', 'mW/h-c2-iso': 'blue', 'mW/h-c3-iso': '#ffd343', 'mW/h-c4-iso': 'green', 'mW/h-c1-ir': 'red', 'mW/h-c2-ir': 'blue', 'mW/h-c3-ir': '#ffd343', 'mW/h-c4-ir': 'green'}

# Create a new figure with a 3x3 grid of subplots
fig, axes = plt.subplots(2,3, figsize=(10, 10))

# Loop over each day and each plot
for row, sheet in enumerate(sheets):
    df = pd.read_excel(file_path, sheet_name=sheets)

    for col in range(3):
        ax = axes[row, col]

        # Set title only for the first row
        if row == 0:
            ax.set_title(plot_titles[col], fontstyle='italic')

        # Plotting logic for each subplot
        #x_col, y_col = columns_for_plots[col]
       # for category, color in colors.items():
           # subset = df[df['mW/h-c1-iso', 'mW/h-c1-ir'] == category]
            #ax.scatter(subset[x_col], subset[y_col], color=color, label=category if col == 0 and row == 0 else "")
           # ax.plot(df[xslope], df[yslope], color='black', linewidth=2)

 # Customize axis labels and ticks
        if row == 2:  # Only for the last row
            ax.set_xlabel('Infrared Thermography Chamber (J/g)', fontsize=lfs, weight='bold', color='k')
        else:
            ax.set_xticklabels([])  # Remove x-axis tick labels for the first and second rows

        if col == 0:  # Only for the first column
            ax.set_ylabel('Isothermal Calorimetry (J/g)', fontsize=lfs, weight='bold', color='k')
        else:
            ax.set_yticklabels([])  # Remove y-axis tick labels for the second and third columns

        ax = customize_ticks(ax, x_major=0.1, x_minor=0.1, y_major=0.1, y_minor=0.1)
        ax.set_xlim(0, 0.75)
        ax.set_ylim(0, 0.75)

# Set shared x-axis and y-axis titles
fig.supxlabel('Heat of Hydration (mW/g)', fontsize=lfs, weight='bold', color='k')
fig.supylabel('Time (hrs)', fontsize=lfs, weight='bold', color='k')

# Adjust layout
plt.tight_layout()

# Save the plot
filename = os.path.join(r'C:\Users\brandyd2\Downloads', "Hydration Curve Nov 2023.png")
fig.savefig(filename, dpi=300, bbox_inches='tight')

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 73
#      71 # Loop over each day and each plot
#      72 for row, sheet in enumerate(sheets):
# ---> 73     df = pd.read_excel(file_path, sheet_name=sheets)
#      75     for col in range(3):
#      76         ax = axes[row, col]
#
# File C:\Anaconda\Lib\site-packages\pandas\io\excel\_base.py:486, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
#     482         "an ExcelFile - ExcelFile already has the engine set"
#     483     )
#     485 try:
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
from matplotlib.ticker import MultipleLocator

# Function to customize ticks on the axes
def customize_ticks(ax, x_major, x_minor, y_major, y_minor):
    ax.xaxis.set_major_locator(MultipleLocator(x_major))
    ax.xaxis.set_minor_locator(MultipleLocator(x_minor))
    ax.yaxis.set_major_locator(MultipleLocator(y_major))
    ax.yaxis.set_minor_locator(MultipleLocator(y_minor))
    ax.tick_params(axis='both', which='major', length=5, width=0.5, labelsize=12)
    ax.tick_params(axis='both', which='minor', length=2.5, width=0.5)
    return ax

# Font properties for the plot
plt.rc('font', family='Times New Roman', weight='regular', size=12)
lfs = 12  # Label font size

# File path for the Excel data
file_path = r'C:\Users\brandyd2\Downloads\231201_Infrared and Isothermal Data_Paste_Diggs_V14.xlsx'
sheets = ['Hours 40% Trail 7_Isocal', 'Hours 40% Trial 7_Infrared', 
          'Hours 55% Trial 7_Isocal', 'Hours 55% Trial 7_Infrared', 
          'Hours 70% Trail 7_Isocal', 'Hours 70% Trial 7_Infrared']

# Plot titles and column names
plot_titles = ['0.40 w/c Ratio', '0.55 w/c Ratio', '0.70 w/c Ratio']
# [Define columns_for_plots as needed]

# Colors for each sample category
colors = {'mW/h-c1-iso': 'red', 'mW/h-c2-iso': 'blue', 'mW/h-c3-iso': '#ffd343', 
          'mW/h-c4-iso': 'green', 'mW/h-c1-ir': 'red', 'mW/h-c2-ir': 'blue', 
          'mW/h-c3-ir': '#ffd343', 'mW/h-c4-ir': 'green'}

# Create a 2x3 grid of subplots
fig, axes = plt.subplots(2, 3, figsize=(10, 10))

for i, sheet in enumerate(sheets[:3]):
    df = pd.read_excel(file_path, sheet_name=sheets)
    for j in range(3):
        ax = axes[i, j]
        # Set plot title
        ax.set_title(plot_titles[j], fontstyle='italic')
        # [Add plotting logic here, e.g., ax.plot or ax.scatter]

        # Customize axis labels and ticks
        ax.set_xlabel('Infrared Thermography Chamber (J/g)', fontsize=lfs)
        ax.set_ylabel('Isothermal Calorimetry (J/g)', fontsize=lfs)
        ax = customize_ticks(ax, x_major=0.1, x_minor=0.1, y_major=0.1, y_minor=0.1)

# Set shared x-axis and y-axis titles
fig.supxlabel('Heat of Hydration (mW/g)', fontsize=lfs, weight='bold', color='k')
fig.supylabel('Time (hrs)', fontsize=lfs, weight='bold', color='k')

plt.tight_layout()

# Save the plot
filename = os.path.join(r'C:\Users\brandyd2\Downloads', "Hydration Curve Nov 2023.png")
fig.savefig(filename, dpi=300, bbox_inches='tight')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 39
#      36 fig, axes = plt.subplots(2, 3, figsize=(10, 10))
#      38 for i, sheet in enumerate(sheets[:3]):
# ---> 39     df = pd.read_excel(file_path, sheet_name=sheets)
#      40     for j in range(3):
#      41         ax = axes[i, j]
#
# File C:\Anaconda\Lib\site-packages\pandas\io\excel\_base.py:486, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     480     raise ValueError(
#     481         "Engine should not be specified when passing "
#     482         "an ExcelFile - ExcelFile already has the engine set"
#     483     )
#     485 try:
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
from matplotlib.ticker import MultipleLocator

# Function to customize ticks on the axes
def customize_ticks(ax, x_major, x_minor, y_major, y_minor):
    ax.xaxis.set_major_locator(MultipleLocator(x_major))
    ax.xaxis.set_minor_locator(MultipleLocator(x_minor))
    ax.yaxis.set_major_locator(MultipleLocator(y_major))
    ax.yaxis.set_minor_locator(MultipleLocator(y_minor))
    ax.tick_params(axis='both', which='major', length=5, width=0.5, labelsize=12)
    ax.tick_params(axis='both', which='minor', length=2.5, width=0.5)
    return ax

# Font properties for the plot
plt.rc('font', family='Times New Roman', weight='regular', size=12)
lfs = 12  # Label font size

# File path for the Excel data
file_path = r'C:\Users\brandyd2\Downloads\231201_Infrared and Isothermal Data_Paste_Diggs_V14.xlsx'
sheets = ['Trial 7_Complete_40_Isocal', 'Trial 7_Complete_40_Infrared', 
          'Trial 7_Complete_55_Isocal', 'Trial 7_Complete_55_Infrared', 
          'Trial 7_Complete_70_Isocal', 'Trial 7_Complete_70_Infrared']

# Plot titles and column names
plot_titles = ['0.40 w/c Ratio', '0.55 w/c Ratio', '0.70 w/c Ratio']
# [Define columns_for_plots as needed]

# Colors for each sample category
colors = {'mW/h-c1-iso': 'red', 'mW/h-c2-iso': 'blue', 'mW/h-c3-iso': '#ffd343', 
          'mW/h-c4-iso': 'green', 'mW/h-c1-ir': 'red', 'mW/h-c2-ir': 'blue', 
          'mW/h-c3-ir': '#ffd343', 'mW/h-c4-ir': 'green'}

# Create a 2x3 grid of subplots
fig, axes = plt.subplots(2, 3, figsize=(10, 10))

for i, sheet in enumerate(sheets):
    df = pd.read_excel(file_path, sheet_name=sheet)
    ax = axes[i // 3, i % 3]  # Correct subplot indexing
    # Set plot title
    ax.set_title(plot_titles[i % 3], fontstyle='italic')
    # [Add your plotting logic here, e.g., ax.plot or ax.scatter]

    # Customize axis labels and ticks
    if i // 3 == 0:  # First row
        ax.set_xlabel('Isothermal Calorimetry (J/g)', fontsize=lfs)
    else:  # Second row
        ax.set_xlabel('Infrared Thermography Chamber (J/g)', fontsize=lfs)
    
    ax.set_ylabel('Heat of Hydration (mW/g)', fontsize=lfs)
    ax = customize_ticks(ax, x_major=0.1, x_minor=0.1, y_major=0.1, y_minor=0.1)

# Set shared x-axis and y-axis titles
fig.supxlabel('Time (hrs)', fontsize=lfs, weight='bold', color='k')
fig.supylabel('Heat Flow (mW/g)', fontsize=lfs, weight='bold', color='k')

plt.tight_layout()

# Save the plot
filename = os.path.join(r'C:\Users\brandyd2\Downloads', "Hydration Curve Nov 2023.png")
fig.savefig(filename, dpi=300, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
from matplotlib.ticker import MultipleLocator

# Function to customize ticks on the axes
def customize_ticks(ax, x_major, x_minor, y_major, y_minor):
    ax.xaxis.set_major_locator(MultipleLocator(x_major))
    ax.xaxis.set_minor_locator(MultipleLocator(x_minor))
    ax.yaxis.set_major_locator(MultipleLocator(y_major))
    ax.yaxis.set_minor_locator(MultipleLocator(y_minor))
    ax.tick_params(axis='both', which='major', length=5, width=0.5, labelsize=12)
    ax.tick_params(axis='both', which='minor', length=2.5, width=0.5)
    return ax

# Font properties for the plot
plt.rc('font', family='Times New Roman', weight='regular', size=12)
lfs = 12  # Label font size

file_path = r'C:\Users\brandyd2\Downloads\231201_Infrared and Isothermal Data_Paste_Diggs_V14.xlsx'
sheets = ['Trial 7_Complete_40_Isocal', 'Trial 7_Complete_40_Infrared', 
          'Trial 7_Complete_55_Isocal', 'Trial 7_Complete_55_Infrared', 
          'Trial 7_Complete_70_Isocal', 'Trial 7_Complete_70_Infrared']

# Plot titles and column names
plot_titles = ['0.40 w/c Ratio', '0.55 w/c Ratio', '0.70 w/c Ratio']


# Define titles and column names for different methods
plot_titles = ['0.40 w/c Ratio', '0.55 w/c Ratio', '0.70 w/c Ratio']
columns_for_plots = [
    ('Time-c1-iso', 'mW/h-c1-iso', 'Time-c2-iso', 'mW/h-c2-iso', 'Time-c3-iso', 'mW/h-c3-iso', 'Time-c4-iso', 'mW/h-c4-iso'),
    ('Time-c1-ir', 'mW/h-c1-ir', 'Time-c2-ir', 'mW/h-c2-ir', 'Time-c3-ir', 'mW/h-c3-ir', 'Time-c4-ir', 'mW/h-c4-ir'),
    ('Time-c1-iso', 'mW/h-c1-iso', 'Time-c2-iso', 'mW/h-c2-iso', 'Time-c3-iso', 'mW/h-c3-iso', 'Time-c4-iso', 'mW/h-c4-iso'),
    ('Time-c1-ir', 'mW/h-c1-ir', 'Time-c2-ir', 'mW/h-c2-ir', 'Time-c3-ir', 'mW/h-c3-ir', 'Time-c4-ir', 'mW/h-c4-ir'),
    ('Time-c1-iso', 'mW/h-c1-iso', 'Time-c2-iso', 'mW/h-c2-iso', 'Time-c3-iso', 'mW/h-c3-iso', 'Time-c4-iso', 'mW/h-c4-iso'),
    ('Time-c1-ir', 'mW/h-c1-ir', 'Time-c2-ir', 'mW/h-c2-ir', 'Time-c3-ir', 'mW/h-c3-ir', 'Time-c4-ir', 'mW/h-c4-ir'),
    
]

# Colors for each sample category
colors = {'mW/h-c1-iso': 'red', 'mW/h-c2-iso': 'blue', 'mW/h-c3-iso': '#ffd343', 
          'mW/h-c4-iso': 'green', 'mW/h-c1-ir': 'red', 'mW/h-c2-ir': 'blue', 
          'mW/h-c3-ir': '#ffd343', 'mW/h-c4-ir': 'green'}

# Create a 2x3 grid of subplots
fig, axes = plt.subplots(2, 3, figsize=(10, 10))

for i, sheet in enumerate(sheets):
    df = pd.read_excel(file_path, sheet_name=sheet)
    ax = axes[i // 3, i % 3]  # Correct subplot indexing
    # Set plot title
    ax.set_title(plot_titles[i % 3], fontstyle='italic')
    # [Add your plotting logic here, e.g., ax.plot or ax.scatter]

    # Customize axis labels and ticks
    if i // 3 == 0:  # First row
        ax.set_xlabel('Isothermal Calorimetry (J/g)', fontsize=lfs)
    else:  # Second row
        ax.set_xlabel('Infrared Thermography Chamber (J/g)', fontsize=lfs)
    
    ax.set_ylabel('Heat of Hydration (mW/g)', fontsize=lfs)
    ax = customize_ticks(ax, x_major=0.1, x_minor=0.1, y_major=0.1, y_minor=0.1)

# Set shared x-axis and y-axis titles
fig.supxlabel('Time (hrs)', fontsize=lfs, weight='bold', color='k')
fig.supylabel('Heat Flow (mW/g)', fontsize=lfs, weight='bold', color='k')

plt.tight_layout()

# Save the plot
filename = os.path.join(r'C:\Users\brandyd2\Downloads', "Hydration Curve Nov 2023.png")
fig.savefig(filename, dpi=300, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
from matplotlib.ticker import MultipleLocator

# Function to customize ticks on the axes
def customize_ticks(ax, x_major, x_minor, y_major, y_minor):
    ax.xaxis.set_major_locator(MultipleLocator(x_major))
    ax.xaxis.set_minor_locator(MultipleLocator(x_minor))
    ax.yaxis.set_major_locator(MultipleLocator(y_major))
    ax.yaxis.set_minor_locator(MultipleLocator(y_minor))
    ax.tick_params(axis='both', which='major', length=5, width=0.5, labelsize=12)
    ax.tick_params(axis='both', which='minor', length=2.5, width=0.5)
    return ax

# Font properties for the plot
plt.rc('font', family='Times New Roman', weight='regular', size=12)
lfs = 12  # Label font size

file_path = r'C:\Users\brandyd2\Downloads\231201_Infrared and Isothermal Data_Paste_Diggs_V14_Heat and Cumlative Heat Only.xlsx'
sheets = ['Trial 7_Complete_40_Isocal', 'Trial 7_Complete_40_Infrared', 
          'Trial 7_Complete_55_Isocal', 'Trial 7_Complete_55_Infrared', 
          'Trial 7_Complete_70_Isocal', 'Trial 7_Complete_70_Infrared']

# Define titles and column names for different methods
plot_titles = ['0.40 w/c Ratio', '0.55 w/c Ratio', '0.70 w/c Ratio']
columns_for_plots = [
('Time-c1-iso40', 'mW/h-c1-iso40', 'Time-c2-iso40', 'mW/h-c2-iso40', 'Time-c3-iso40', 'mW/h-c3-iso40', 'Time-c4-iso40', 'mW/h-c4-iso40'),('Time-c1-iso55', 'mW/h-c1-iso55', 'Time-c2-iso55', 'mW/h-c2-iso55', 'Time-c3-iso55', 'mW/h-c3-iso55', 'Time-c4-iso55', 'mW/h-c4-iso55'), ('Time-c1-iso70', 'mW/h-c1-iso70', 'Time-c2-iso70', 'mW/h-c2-iso70', 'Time-c3-iso70', 'mW/h-c3-iso70', 'Time-c4-iso70', 'mW/h-c4-iso70'),
('Time-c1-ir40', 'mW/h-c1-ir40', 'Time-c2-ir40', 'mW/h-c2-ir40', 'Time-c3-ir40', 'mW/h-c3-ir40', 'Time-c4-ir40', 'mW/h-c4-ir40'),
('Time-c1-ir55', 'mW/h-c1-ir55', 'Time-c2-ir55', 'mW/h-c2-ir55', 'Time-c3-ir55', 'mW/h-c3-ir55', 'Time-c4-ir55', 'mW/h-c4-ir55'),
('Time-c1-ir70', 'mW/h-c1-ir70', 'Time-c2-ir70', 'mW/h-c2-ir70', 'Time-c3-ir70', 'mW/h-c3-ir70', 'Time-c4-ir70', 'mW/h-c4-ir70'),   
]

# Colors for each sample category
colors = {'mW/h-c1-iso40': 'red', 'mW/h-c2-iso40': 'blue', 'mW/h-c3-iso40': '#ffd343', 
          'mW/h-c4-iso40': 'green', 'mW/h-c1-ir40': 'red', 'mW/h-c2-ir40': 'blue', 
          'mW/h-c3-ir40': '#ffd343', 'mW/h-c4-ir40': 'green', 'mW/h-c1-iso55': 'red', 'mW/h-c2-iso55': 'blue', 'mW/h-c3-iso55': '#ffd343', 
          'mW/h-c4-iso55': 'green', 'mW/h-c1-ir55': 'red', 'mW/h-c2-ir55': 'blue', 
          'mW/h-c3-ir55': '#ffd343', 'mW/h-c4-ir55': 'green', 'mW/h-c1-iso70': 'red', 'mW/h-c2-iso70': 'blue', 'mW/h-c3-iso70': '#ffd343', 
          'mW/h-c4-iso70': 'green', 'mW/h-c1-ir70': 'red', 'mW/h-c2-ir70': 'blue', 
          'mW/h-c3-ir70': '#ffd343', 'mW/h-c4-ir70': 'green'}

# Create a 2x3 grid of subplots
fig, axes = plt.subplots(2, 3, figsize=(10, 10))

for i, sheet in enumerate(sheets):
    df = pd.read_excel(file_path, sheet_name=sheet)
    ax = axes[i // 3, i % 3]  # Correct subplot indexing
    ax.set_title(plot_titles[i % 3], fontstyle='italic')

    # Plotting logic
    time_columns = [col for col in columns_for_plots[i] if 'Time' in col]
    data_columns = [col for col in columns_for_plots[i] if 'mW/h' in col]

    for time_col, data_col in zip(time_columns, data_columns):
        if time_col in df.columns and data_col in df.columns:
            ax.plot(df[time_col], df[data_col], label=data_col, color=colors.get(data_col, 'blue'))

    if i // 3 == 0:  # First row
        ax.set_ylabel('Isothermal Calorimetry (J/g)', fontsize=lfs)
        ax = customize_ticks(ax, x_major=10, x_minor=5, y_major=12.0, y_minor=1.0)
        ax.legend()
    else:  # Second row
        ax.set_ylabel('Infrared Thermography Chamber (J/g)', fontsize=lfs)
        ax = customize_ticks(ax, x_major=10, x_minor=5, y_major=12.0, y_minor=1.0)
        ax.legend()

# Set shared x-axis and y-axis titles
fig.supxlabel('Time (hrs)', fontsize=lfs, weight='bold', color='k')
fig.supylabel('Heat Flow (mW/g)', fontsize=lfs, weight='bold', color='k')

plt.tight_layout()

# Save the plot
filename = os.path.join(r'C:\Users\brandyd2\Downloads', "Hydration Curve Nov 2023.png")
fig.savefig(filename, dpi=300, bbox_inches='tight')

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df
# Out:
#      Time-c1-ir70  mW/h-c1-ir70  Cumulative-c1-ir70  1/t^0.5-c1-ir  \
# 0        0.085278     12.836017            8.636153       3.424381
# 1        0.335274      6.371053           17.398763       1.727030
# 2        0.918593      1.981179           22.122050       1.043370
# 3        2.001904      0.443005           23.932128       0.706770
# 4        3.418541      0.267412           25.611680       0.540853
# ..            ...           ...                 ...            ...
# 390           NaN           NaN                 NaN            NaN
# 391           NaN           NaN                 NaN            NaN
# 392           NaN           NaN                 NaN            NaN
# 393           NaN           NaN                 NaN            NaN
# 394           NaN           NaN                 NaN            NaN
#
#      Qinf-c1-ir   α-c1-ir  Time in Hours-c1-ir  α-c1-ir.1  Unnamed: 8  \
# 0        206.11  0.041901                  1.0   0.107331         NaN
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
from matplotlib.ticker import MultipleLocator

# Function to customize ticks on the axes
def customize_ticks(ax, x_major, x_minor, y_major, y_minor):
    ax.xaxis.set_major_locator(MultipleLocator(x_major))
    ax.xaxis.set_minor_locator(MultipleLocator(x_minor))
    ax.yaxis.set_major_locator(MultipleLocator(y_major))
    ax.yaxis.set_minor_locator(MultipleLocator(y_minor))
    ax.tick_params(axis='both', which='major', length=5, width=0.5, labelsize=12)
    ax.tick_params(axis='both', which='minor', length=2.5, width=0.5)
    return ax

# Font properties for the plot
plt.rc('font', family='Times New Roman', weight='regular', size=12)
lfs = 12  # Label font size

# File path for the Excel data
file_path = r'C:\Users\brandyd2\Downloads\231201_Infrared and Isothermal Data_Paste_Diggs_V14_Heat and Cumlative Heat Only.xlsx'
sheets = ['Trial 7_Complete_40_Isocal', 'Trial 7_Complete_40_Infrared', 
          'Trial 7_Complete_55_Isocal', 'Trial 7_Complete_55_Infrared', 
          'Trial 7_Complete_70_Isocal', 'Trial 7_Complete_70_Infrared']

# Define titles and column names for different methods
plot_titles = ['0.40 w/c Ratio', '0.55 w/c Ratio', '0.70 w/c Ratio']
columns_for_plots = [
('Time-c1-iso40', 'mW/h-c1-iso40', 'Time-c2-iso40', 'mW/h-c2-iso40', 'Time-c3-iso40', 'mW/h-c3-iso40', 'Time-c4-iso40', 'mW/h-c4-iso40'),('Time-c1-iso55', 'mW/h-c1-iso55', 'Time-c2-iso55', 'mW/h-c2-iso55', 'Time-c3-iso55', 'mW/h-c3-iso55', 'Time-c4-iso55', 'mW/h-c4-iso55'), ('Time-c1-iso70', 'mW/h-c1-iso70', 'Time-c2-iso70', 'mW/h-c2-iso70', 'Time-c3-iso70', 'mW/h-c3-iso70', 'Time-c4-iso70', 'mW/h-c4-iso70'),
('Time-c1-ir40', 'mW/h-c1-ir40', 'Time-c2-ir40', 'mW/h-c2-ir40', 'Time-c3-ir40', 'mW/h-c3-ir40', 'Time-c4-ir40', 'mW/h-c4-ir40'),
('Time-c1-ir55', 'mW/h-c1-ir55', 'Time-c2-ir55', 'mW/h-c2-ir55', 'Time-c3-ir55', 'mW/h-c3-ir55', 'Time-c4-ir55', 'mW/h-c4-ir55'),
('Time-c1-ir70', 'mW/h-c1-ir70', 'Time-c2-ir70', 'mW/h-c2-ir70', 'Time-c3-ir70', 'mW/h-c3-ir70', 'Time-c4-ir70', 'mW/h-c4-ir70'),   
]

# Colors for each sample category
colors = {'mW/h-c1-iso40': 'red', 'mW/h-c2-iso40': 'blue', 'mW/h-c3-iso40': '#ffd343', 
          'mW/h-c4-iso40': 'green', 'mW/h-c1-iso55': 'red', 'mW/h-c2-iso55': 'blue', 'mW/h-c3-iso55': '#ffd343', 
          'mW/h-c4-iso55': 'green','mW/h-c1-iso70': 'red', 'mW/h-c2-iso70': 'blue', 'mW/h-c3-iso70': '#ffd343', 
          'mW/h-c4-iso70': 'green','mW/h-c1-ir40': 'red', 'mW/h-c2-ir40': 'blue', 
          'mW/h-c3-ir40': '#ffd343', 'mW/h-c4-ir40': 'green','mW/h-c1-ir55': 'red', 'mW/h-c2-ir55': 'blue', 
          'mW/h-c3-ir55': '#ffd343', 'mW/h-c4-ir55': 'green', 'mW/h-c1-ir70': 'red', 'mW/h-c2-ir70': 'blue', 
          'mW/h-c3-ir70': '#ffd343', 'mW/h-c4-ir70': 'green'}

# Create a 2x3 grid of subplots
fig, axes = plt.subplots(2, 3, figsize=(10, 10))

for i, sheet in enumerate(sheets):
    df = pd.read_excel(file_path, sheet_name=sheet)
    ax = axes[i // 3, i % 3]  # Correct subplot indexing
    ax.set_title(plot_titles[i % 3], fontstyle='italic')

    # Plotting logic
    time_columns = [col for col in columns_for_plots[i] if 'Time' in col]
    data_columns = [col for col in columns_for_plots[i] if 'mW/h' in col]

    for time_col, data_col in zip(time_columns, data_columns):
        if time_col in df.columns and data_col in df.columns:
            ax.plot(df[time_col], df[data_col], label=data_col, color=colors.get(data_col, 'blue'))

    if i // 3 == 0:  # First row
        ax.set_ylabel('Isothermal Calorimetry (J/g)', fontsize=lfs)
    else:  # Second row
        ax.set_ylabel('Infrared Thermography Chamber (J/g)', fontsize=lfs)

    ax = customize_ticks(ax, x_major=10, x_minor=5, y_major=12.0, y_minor=1.0)
    ax.legend()
    plt.plot('C1','C2', 'C3','C4')
    plt.legend()
    
# Set shared x-axis and y-axis titles
fig.supxlabel('Time (hrs)', fontsize=lfs, weight='bold', color='k')
fig.supylabel('Heat Flow (mW/g)', fontsize=lfs, weight='bold', color='k')

plt.tight_layout()

# Save the plot
filename = os.path.join(r'C:\Users\brandyd2\Downloads', "Hydration Curve Nov 2023.png")
fig.savefig(filename, dpi=300, bbox_inches='tight')

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
from matplotlib.ticker import MultipleLocator

def customize_ticks(ax, x_major, x_minor, y_major, y_minor):
    ax.xaxis.set_major_locator(MultipleLocator(x_major))
    ax.xaxis.set_minor_locator(MultipleLocator(x_minor))
    ax.yaxis.set_major_locator(MultipleLocator(y_major))
    ax.yaxis.set_minor_locator(MultipleLocator(y_minor))
    ax.tick_params(axis='both', which='major', length=5, width=0.5, labelsize=12)
    ax.tick_params(axis='both', which='minor', length=2.5, width=0.5)
    return ax

plt.rc('font', family='Times New Roman', weight='regular', size=12)
lfs = 12

file_path = r'C:\Users\brandyd2\Downloads\231201_Infrared and Isothermal Data_Paste_Diggs_V14_Heat and Cumlative Heat Only.xlsx'
sheets = ['Trial 7_Complete_40_Isocal', 'Trial 7_Complete_40_Infrared', 
          'Trial 7_Complete_55_Isocal', 'Trial 7_Complete_55_Infrared', 
          'Trial 7_Complete_70_Isocal', 'Trial 7_Complete_70_Infrared']

plot_titles = ['0.40 w/c Ratio', '0.55 w/c Ratio', '0.70 w/c Ratio']
columns_for_plots = [
('Time-c1-iso40', 'mW/h-c1-iso40', 'Time-c2-iso40', 'mW/h-c2-iso40', 'Time-c3-iso40', 'mW/h-c3-iso40', 'Time-c4-iso40', 'mW/h-c4-iso40'),('Time-c1-iso55', 'mW/h-c1-iso55', 'Time-c2-iso55', 'mW/h-c2-iso55', 'Time-c3-iso55', 'mW/h-c3-iso55', 'Time-c4-iso55', 'mW/h-c4-iso55'), ('Time-c1-iso70', 'mW/h-c1-iso70', 'Time-c2-iso70', 'mW/h-c2-iso70', 'Time-c3-iso70', 'mW/h-c3-iso70', 'Time-c4-iso70', 'mW/h-c4-iso70'),
('Time-c1-ir40', 'mW/h-c1-ir40', 'Time-c2-ir40', 'mW/h-c2-ir40', 'Time-c3-ir40', 'mW/h-c3-ir40', 'Time-c4-ir40', 'mW/h-c4-ir40'),
('Time-c1-ir55', 'mW/h-c1-ir55', 'Time-c2-ir55', 'mW/h-c2-ir55', 'Time-c3-ir55', 'mW/h-c3-ir55', 'Time-c4-ir55', 'mW/h-c4-ir55'),
('Time-c1-ir70', 'mW/h-c1-ir70', 'Time-c2-ir70', 'mW/h-c2-ir70', 'Time-c3-ir70', 'mW/h-c3-ir70', 'Time-c4-ir70', 'mW/h-c4-ir70'),   
]
# Colors for each sample category
colors = {'mW/h-c1-iso40': 'red', 'mW/h-c2-iso40': 'blue', 'mW/h-c3-iso40': '#ffd343', 
          'mW/h-c4-iso40': 'green', 'mW/h-c1-iso55': 'red', 'mW/h-c2-iso55': 'blue', 'mW/h-c3-iso55': '#ffd343', 
          'mW/h-c4-iso55': 'green','mW/h-c1-iso70': 'red', 'mW/h-c2-iso70': 'blue', 'mW/h-c3-iso70': '#ffd343', 
          'mW/h-c4-iso70': 'green','mW/h-c1-ir40': 'red', 'mW/h-c2-ir40': 'blue', 
          'mW/h-c3-ir40': '#ffd343', 'mW/h-c4-ir40': 'green','mW/h-c1-ir55': 'red', 'mW/h-c2-ir55': 'blue', 
          'mW/h-c3-ir55': '#ffd343', 'mW/h-c4-ir55': 'green', 'mW/h-c1-ir70': 'red', 'mW/h-c2-ir70': 'blue', 
          'mW/h-c3-ir70': '#ffd343', 'mW/h-c4-ir70': 'green'}

fig, axes = plt.subplots(2, 3, figsize=(10, 10))

for i, sheet in enumerate(sheets):
    df = pd.read_excel(file_path, sheet_name=sheet)
    ax = axes[i // 3, i % 3]
    ax.set_title(plot_titles[i % 3], fontstyle='italic')

    time_columns = [col for col in columns_for_plots[i] if 'Time' in col]
    data_columns = [col for col in columns_for_plots[i] if 'mW/h' in col]

    for time_col, data_col in zip(time_columns, data_columns):
        if time_col in df.columns and data_col in df.columns:
            ax.plot(df[time_col], df[data_col], label=data_col.split('-')[1], color=colors[data_col])

    if i // 3 == 0 and i % 3 == 0:  # First row, first column
        ax.legend(title='Sample Categories')
    if i // 3 == 0:
        ax.set_ylabel('Isothermal Calorimetry (mW/g)', fontsize=lfs)
    else:
        ax.set_ylabel('Infrared Thermography Chamber (mW/g)', fontsize=lfs)

    ax = customize_ticks(ax, x_major=10, x_minor=5, y_major=12.0, y_minor=1.0)

fig.supxlabel('Time (hrs)', fontsize=lfs, weight='bold', color='k')
fig.supylabel('Heat of Hydration (mW/g)', fontsize=lfs, weight='bold', color='k')

plt.tight_layout()

filename = os.path.join(r'C:\Users\brandyd2\Downloads', "Hydration Curve Nov 2023.png")
fig.savefig(filename, dpi=300, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
from matplotlib.ticker import MultipleLocator

def customize_ticks(ax, x_major, x_minor, y_major, y_minor):
    ax.xaxis.set_major_locator(MultipleLocator(x_major))
    ax.xaxis.set_minor_locator(MultipleLocator(x_minor))
    ax.yaxis.set_major_locator(MultipleLocator(y_major))
    ax.yaxis.set_minor_locator(MultipleLocator(y_minor))
    ax.tick_params(axis='both', which='major', length=5, width=0.5, labelsize=12)
    ax.tick_params(axis='both', which='minor', length=2.5, width=0.5)
    return ax

plt.rc('font', family='Times New Roman', weight='regular', size=12)
lfs = 12

file_path = r'C:\Users\brandyd2\Downloads\231201_Infrared and Isothermal Data_Paste_Diggs_V14_Heat and Cumlative Heat Only.xlsx'
sheets = ['Trial 7_Complete_40_Isocal', 'Trial 7_Complete_55_Isocal','Trial 7_Complete_70_Isocal','Trial 7_Complete_40_Infrared', 'Trial 7_Complete_55_Infrared', 'Trial 7_Complete_70_Infrared']

plot_titles = ['0.40 w/c Ratio', '0.55 w/c Ratio', '0.70 w/c Ratio']
columns_for_plots = [
('Time-c1-iso40', 'mW/h-c1-iso40', 'Time-c2-iso40', 'mW/h-c2-iso40', 'Time-c3-iso40', 'mW/h-c3-iso40', 'Time-c4-iso40', 'mW/h-c4-iso40'),('Time-c1-iso55', 'mW/h-c1-iso55', 'Time-c2-iso55', 'mW/h-c2-iso55', 'Time-c3-iso55', 'mW/h-c3-iso55', 'Time-c4-iso55', 'mW/h-c4-iso55'), ('Time-c1-iso70', 'mW/h-c1-iso70', 'Time-c2-iso70', 'mW/h-c2-iso70', 'Time-c3-iso70', 'mW/h-c3-iso70', 'Time-c4-iso70', 'mW/h-c4-iso70'),
('Time-c1-ir40', 'mW/h-c1-ir40', 'Time-c2-ir40', 'mW/h-c2-ir40', 'Time-c3-ir40', 'mW/h-c3-ir40', 'Time-c4-ir40', 'mW/h-c4-ir40'),
('Time-c1-ir55', 'mW/h-c1-ir55', 'Time-c2-ir55', 'mW/h-c2-ir55', 'Time-c3-ir55', 'mW/h-c3-ir55', 'Time-c4-ir55', 'mW/h-c4-ir55'),
('Time-c1-ir70', 'mW/h-c1-ir70', 'Time-c2-ir70', 'mW/h-c2-ir70', 'Time-c3-ir70', 'mW/h-c3-ir70', 'Time-c4-ir70', 'mW/h-c4-ir70'),   
]
# Colors for each sample category
colors = {'mW/h-c1-iso40': 'red', 'mW/h-c2-iso40': 'blue', 'mW/h-c3-iso40': '#ffd343', 
          'mW/h-c4-iso40': 'green', 'mW/h-c1-iso55': 'red', 'mW/h-c2-iso55': 'blue', 'mW/h-c3-iso55': '#ffd343', 
          'mW/h-c4-iso55': 'green','mW/h-c1-iso70': 'red', 'mW/h-c2-iso70': 'blue', 'mW/h-c3-iso70': '#ffd343', 
          'mW/h-c4-iso70': 'green','mW/h-c1-ir40': 'red', 'mW/h-c2-ir40': 'blue', 
          'mW/h-c3-ir40': '#ffd343', 'mW/h-c4-ir40': 'green','mW/h-c1-ir55': 'red', 'mW/h-c2-ir55': 'blue', 
          'mW/h-c3-ir55': '#ffd343', 'mW/h-c4-ir55': 'green', 'mW/h-c1-ir70': 'red', 'mW/h-c2-ir70': 'blue', 
          'mW/h-c3-ir70': '#ffd343', 'mW/h-c4-ir70': 'green'}

fig, axes = plt.subplots(2, 3, figsize=(8,6))

for i, sheet in enumerate(sheets):
    df = pd.read_excel(file_path, sheet_name=sheet)
    print(f"Processing sheet: {sheet}")
    ax = axes[i // 3, i % 3]
    if i // 3 == 0:
        ax.set_title(plot_titles[i % 3], fontstyle='italic')
    
    time_columns = [col for col in columns_for_plots[i] if 'Time' in col]
    data_columns = [col for col in columns_for_plots[i] if 'mW/h' in col]

    for time_col, data_col in zip(time_columns, data_columns):
        if time_col in df.columns and data_col in df.columns:
            print(f"Plotting {data_col} against {time_col} in sheet {sheet}")
            ax.plot(df[time_col], df[data_col], label=data_col.split('-')[1], color=colors.get(data_col, 'blue'))
        else:
            print(f"Column {time_col} or {data_col} not found in sheet {sheet}")

   # if i // 3 == 0 and i % 3 == 0:  # First row, first column
    #    ax.legend(title='Sample Categories')
    if i // 3 == 0:
        ax.set_ylabel('Isothermal Calorimetry (mW/g)', fontsize=lfs)
    else:
        ax.set_ylabel('Infrared Thermography Chamber (mW/g)', fontsize=lfs)
    
    if row == 2:  # Only for the last row
        ax.set_xlabel('', fontsize=lfs, weight='bold', color='k')
    else:
        ax.set_xticklabels([])  # Remove x-axis tick labels for the first and second rows

    if col == 0:  # Only for the first column
        ax.set_ylabel('', fontsize=lfs, weight='bold', color='k')
    else:
        ax.set_yticklabels([])  # Remove y-axis tick labels for the second and third columns    
    
    

    ax = customize_ticks(ax, x_major=10, x_minor=5, y_major=12.0, y_minor=1.0)
    ax.set_xlim(0, 70)
    ax.set_ylim(0, 5)

fig.supxlabel('Time (hrs)', fontsize=lfs, weight='bold', color='k')
fig.supylabel('Heat of Hydration (mW/g)', fontsize=lfs, weight='bold', color='k')

plt.tight_layout()

filename = os.path.join(r'C:\Users\brandyd2\Downloads', "Hydration Curve Nov 2023.png")
fig.savefig(filename, dpi=300, bbox_inches='tight')

plt.show()
# Out:
# Processing sheet: Trial 7_Complete_40_Isocal
# Plotting mW/h-c1-iso40 against Time-c1-iso40 in sheet Trial 7_Complete_40_Isocal
# Plotting mW/h-c2-iso40 against Time-c2-iso40 in sheet Trial 7_Complete_40_Isocal
# Plotting mW/h-c3-iso40 against Time-c3-iso40 in sheet Trial 7_Complete_40_Isocal
# Plotting mW/h-c4-iso40 against Time-c4-iso40 in sheet Trial 7_Complete_40_Isocal
# Processing sheet: Trial 7_Complete_55_Isocal
# Plotting mW/h-c1-iso55 against Time-c1-iso55 in sheet Trial 7_Complete_55_Isocal
# Plotting mW/h-c2-iso55 against Time-c2-iso55 in sheet Trial 7_Complete_55_Isocal
# Plotting mW/h-c3-iso55 against Time-c3-iso55 in sheet Trial 7_Complete_55_Isocal
# Plotting mW/h-c4-iso55 against Time-c4-iso55 in sheet Trial 7_Complete_55_Isocal
# Processing sheet: Trial 7_Complete_70_Isocal
# Plotting mW/h-c1-iso70 against Time-c1-iso70 in sheet Trial 7_Complete_70_Isocal
# Plotting mW/h-c2-iso70 against Time-c2-iso70 in sheet Trial 7_Complete_70_Isocal
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
from matplotlib.ticker import MultipleLocator

def customize_ticks(ax, x_major, x_minor, y_major, y_minor):
    ax.xaxis.set_major_locator(MultipleLocator(x_major))
    ax.xaxis.set_minor_locator(MultipleLocator(x_minor))
    ax.yaxis.set_major_locator(MultipleLocator(y_major))
    ax.yaxis.set_minor_locator(MultipleLocator(y_minor))
    ax.tick_params(axis='both', which='major', length=5, width=0.5, labelsize=12)
    ax.tick_params(axis='both', which='minor', length=2.5, width=0.5)
    return ax

plt.rc('font', family='Times New Roman', weight='regular', size=12)
lfs = 12

file_path = r'C:\Users\brandyd2\Downloads\231201_Infrared and Isothermal Data_Paste_Diggs_V14_Heat and Cumlative Heat Only.xlsx'
sheets = ['Trial 7_Complete_40_Isocal', 'Trial 7_Complete_55_Isocal', 'Trial 7_Complete_70_Isocal', 
          'Trial 7_Complete_40_Infrared', 'Trial 7_Complete_55_Infrared', 'Trial 7_Complete_70_Infrared']

plot_titles = ['0.40 w/c Ratio', '0.55 w/c Ratio', '0.70 w/c Ratio']
columns_for_plots = [
('Time-c1-iso40', 'mW/h-c1-iso40', 'Time-c2-iso40', 'mW/h-c2-iso40', 'Time-c3-iso40', 'mW/h-c3-iso40', 'Time-c4-iso40', 'mW/h-c4-iso40'),('Time-c1-iso55', 'mW/h-c1-iso55', 'Time-c2-iso55', 'mW/h-c2-iso55', 'Time-c3-iso55', 'mW/h-c3-iso55', 'Time-c4-iso55', 'mW/h-c4-iso55'), ('Time-c1-iso70', 'mW/h-c1-iso70', 'Time-c2-iso70', 'mW/h-c2-iso70', 'Time-c3-iso70', 'mW/h-c3-iso70', 'Time-c4-iso70', 'mW/h-c4-iso70'),
('Time-c1-ir40', 'mW/h-c1-ir40', 'Time-c2-ir40', 'mW/h-c2-ir40', 'Time-c3-ir40', 'mW/h-c3-ir40', 'Time-c4-ir40', 'mW/h-c4-ir40'),
('Time-c1-ir55', 'mW/h-c1-ir55', 'Time-c2-ir55', 'mW/h-c2-ir55', 'Time-c3-ir55', 'mW/h-c3-ir55', 'Time-c4-ir55', 'mW/h-c4-ir55'),
('Time-c1-ir70', 'mW/h-c1-ir70', 'Time-c2-ir70', 'mW/h-c2-ir70', 'Time-c3-ir70', 'mW/h-c3-ir70', 'Time-c4-ir70', 'mW/h-c4-ir70'),   
]
# Colors for each sample category
colors = {'mW/h-c1-iso40': 'red', 'mW/h-c2-iso40': 'blue', 'mW/h-c3-iso40': '#ffd343', 
          'mW/h-c4-iso40': 'green', 'mW/h-c1-iso55': 'red', 'mW/h-c2-iso55': 'blue', 'mW/h-c3-iso55': '#ffd343', 
          'mW/h-c4-iso55': 'green','mW/h-c1-iso70': 'red', 'mW/h-c2-iso70': 'blue', 'mW/h-c3-iso70': '#ffd343', 
          'mW/h-c4-iso70': 'green','mW/h-c1-ir40': 'red', 'mW/h-c2-ir40': 'blue', 
          'mW/h-c3-ir40': '#ffd343', 'mW/h-c4-ir40': 'green','mW/h-c1-ir55': 'red', 'mW/h-c2-ir55': 'blue', 
          'mW/h-c3-ir55': '#ffd343', 'mW/h-c4-ir55': 'green', 'mW/h-c1-ir70': 'red', 'mW/h-c2-ir70': 'blue', 
          'mW/h-c3-ir70': '#ffd343', 'mW/h-c4-ir70': 'green'}


fig, axes = plt.subplots(2, 3, figsize=(10, 10))

for i, sheet in enumerate(sheets):
    df = pd.read_excel(file_path, sheet_name=sheet)
    ax = axes[i // 3, i % 3]
    if i // 3 == 0:
        ax.set_title(plot_titles[i % 3], fontstyle='italic')

    time_columns = [col for col in columns_for_plots[i] if 'Time' in col]
    data_columns = [col for col in columns_for_plots[i] if 'mW/h' in col]

    for time_col, data_col in zip(time_columns, data_columns):
        if time_col in df.columns and data_col in df.columns:
            ax.plot(df[time_col], df[data_col], label=data_col.split('-')[1], color=colors[data_col])

    # Set y-axis labels for all subplots
    if i // 3 == 0:
        ax.set_ylabel('Isothermal Calorimetry (mW/g)', fontsize=lfs)
    else:
        ax.set_ylabel('Infrared Thermography Chamber (mW/g)', fontsize=lfs)

    # Adjust x-axis tick labels
    if i // 3 == 1:  # Only for the second row
        ax.tick_params(axis='x', labelbottom=True)
    else:
        ax.tick_params(axis='x', labelbottom=False)

    ax = customize_ticks(ax, x_major=10, x_minor=5, y_major=12.0, y_minor=1.0)

fig.supxlabel('Time (hrs)', fontsize=lfs, weight='bold', color='k')
fig.supylabel('Heat of Hydration (mW/g)', fontsize=lfs, weight='bold', color='k')

plt.tight_layout()

# %%
#Datasent Inforamtion
# What is the "name" of the dataset? Cement Paste Data
# Where did you obtain it? I collected the samples
# Where can we obtain it? (i.e., URL): Will be available after first publication.
# What is the license of the dataset? What are we allowed to do with it? None and do not share.
# How big is it in file size and in items? 4,853KB, 


import textwrap
import matplotlib.pyplot as plt
import pandas as pd
import os
from matplotlib.ticker import MultipleLocator

def customize_ticks(ax, x_major, x_minor, y_major, y_minor):
    ax.xaxis.set_major_locator(MultipleLocator(x_major))
    ax.xaxis.set_minor_locator(MultipleLocator(x_minor))
    ax.yaxis.set_major_locator(MultipleLocator(y_major))
    ax.yaxis.set_minor_locator(MultipleLocator(y_minor))
    ax.tick_params(axis='both', which='major', length=5, width=0.5, labelsize=12)
    ax.tick_params(axis='both', which='minor', length=2.5, width=0.5)
    return ax

plt.rc('font', family='Times New Roman', weight='regular', size=12)
lfs = 12

file_path = r'C:\Users\brandyd2\Downloads\231201_Infrared and Isothermal Data_Paste_Diggs_V14_Heat and Cumlative Heat Only.xlsx'
sheets = ['Trial 7_Complete_40_Isocal', 'Trial 7_Complete_55_Isocal', 'Trial 7_Complete_70_Isocal', 
          'Trial 7_Complete_40_Infrared', 'Trial 7_Complete_55_Infrared', 'Trial 7_Complete_70_Infrared']



plot_titles = ['0.40 w/c Ratio', '0.55 w/c Ratio', '0.70 w/c Ratio']
columns_for_plots = [
('Time-c1-iso40', 'mW/h-c1-iso40', 'Time-c2-iso40', 'mW/h-c2-iso40', 'Time-c3-iso40', 'mW/h-c3-iso40', 'Time-c4-iso40', 'mW/h-c4-iso40'),('Time-c1-iso55', 'mW/h-c1-iso55', 'Time-c2-iso55', 'mW/h-c2-iso55', 'Time-c3-iso55', 'mW/h-c3-iso55', 'Time-c4-iso55', 'mW/h-c4-iso55'), ('Time-c1-iso70', 'mW/h-c1-iso70', 'Time-c2-iso70', 'mW/h-c2-iso70', 'Time-c3-iso70', 'mW/h-c3-iso70', 'Time-c4-iso70', 'mW/h-c4-iso70'),
('Time-c1-ir40', 'mW/h-c1-ir40', 'Time-c2-ir40', 'mW/h-c2-ir40', 'Time-c3-ir40', 'mW/h-c3-ir40', 'Time-c4-ir40', 'mW/h-c4-ir40'),
('Time-c1-ir55', 'mW/h-c1-ir55', 'Time-c2-ir55', 'mW/h-c2-ir55', 'Time-c3-ir55', 'mW/h-c3-ir55', 'Time-c4-ir55', 'mW/h-c4-ir55'),
('Time-c1-ir70', 'mW/h-c1-ir70', 'Time-c2-ir70', 'mW/h-c2-ir70', 'Time-c3-ir70', 'mW/h-c3-ir70', 'Time-c4-ir70', 'mW/h-c4-ir70'),   
]
# Colors for each sample category
colors = {'mW/h-c1-iso40': 'red', 'mW/h-c2-iso40': 'blue', 'mW/h-c3-iso40': '#ffd343', 
          'mW/h-c4-iso40': 'green', 'mW/h-c1-iso55': 'red', 'mW/h-c2-iso55': 'blue', 'mW/h-c3-iso55': '#ffd343', 
          'mW/h-c4-iso55': 'green','mW/h-c1-iso70': 'red', 'mW/h-c2-iso70': 'blue', 'mW/h-c3-iso70': '#ffd343', 
          'mW/h-c4-iso70': 'green','mW/h-c1-ir40': 'red', 'mW/h-c2-ir40': 'blue', 
          'mW/h-c3-ir40': '#ffd343', 'mW/h-c4-ir40': 'green','mW/h-c1-ir55': 'red', 'mW/h-c2-ir55': 'blue', 
          'mW/h-c3-ir55': '#ffd343', 'mW/h-c4-ir55': 'green', 'mW/h-c1-ir70': 'red', 'mW/h-c2-ir70': 'blue', 
          'mW/h-c3-ir70': '#ffd343', 'mW/h-c4-ir70': 'green'}

# Define legend labels and colors
legend_labels = {'c1': 'C1', 'c2': 'C2', 'c3': 'C3', 'c4': 'C4'}
legend_colors = {'C1': 'red', 'C2': 'blue', 'C3': '#ffd343', 'C4': 'green'}

fig, axes = plt.subplots(2, 3, figsize=(9, 6))

for i, sheet in enumerate(sheets):
    df = pd.read_excel(file_path, sheet_name=sheet)
    ax = axes[i // 3, i % 3]
    if i // 3 == 0:
        ax.set_title(plot_titles[i % 3], fontstyle='italic')

    time_columns = [col for col in columns_for_plots[i] if 'Time' in col]
    data_columns = [col for col in columns_for_plots[i] if 'mW/h' in col]

    for time_col, data_col in zip(time_columns, data_columns):
        if time_col in df.columns and data_col in df.columns:
            category = data_col.split('-')[1].split('iso')[0].split('ir')[0]
            label = legend_labels.get(category, category)
            color = legend_colors.get(label, 'black')
            ax.plot(df[time_col], df[data_col], label=label, color=color)

    if i // 3 == 0 and i % 3 == 0:  # First row, first column
        ax.legend(fontsize='small')

    # Set y-axis labels and tick labels
    if i % 3 == 0:  # Only for the first column of each row
        if i // 3 == 0:
            ax.set_ylabel('Isothermal Calorimetry', fontsize=lfs, rotation=90, labelpad=15, ha='center', va='center')
            ax.tick_params(axis='y', labelleft=True)  # Enable y-axis tick labels
        else:
            label_text=('Infrared Thermography Chamber')
            wrapped_label = textwrap.fill(label_text, width=0.1)  # Wrapping the text
            ax.set_ylabel(label_text, fontsize=lfs, rotation=90, labelpad=15, ha='center', va='center')
            ax.tick_params(axis='y', labelleft=True)  # Enable y-axis tick labels
    else:
        ax.set_ylabel('')  # Remove y-label for other columns
        ax.tick_params(axis='y', labelleft=False)  # Disable y-axis tick labels

    # Adjust x-axis tick labels
    if i // 3 == 1:  # Only for the second row
        ax.tick_params(axis='x', labelbottom=True)
    else:
        ax.tick_params(axis='x', labelbottom=False)

    ax = customize_ticks(ax, x_major=10, x_minor=5, y_major=1, y_minor=.50)
    ax.set_xlim(0, 70)
    ax.set_ylim(0, 5)


fig.supxlabel('Time (hrs)', fontsize=lfs, weight='bold', color='k')
fig.supylabel('Heat of Hydration (mW/g)', fontsize=lfs, weight='bold', color='k')

plt.tight_layout()

filename = os.path.join(r'C:\Users\brandyd2\Downloads', "Hydration Curve Nov 2023.png")
fig.savefig(filename, dpi=300, bbox_inches='tight')

plt.show()
